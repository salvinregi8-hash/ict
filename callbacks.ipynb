# %%
import numpy as np
from tensorflow.keras import Sequential
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten
from keras import regularizers
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical as to_catagorical
from tensorflow.keras.callbacks import TensorBoard
from os.path import join
import tensorflow as tf

# %%
(x_train,y_train),(x_test,y_test) =mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
y_train=to_catagorical(y_train,num_classes=10)
y_test=to_catagorical(y_test,num_classes=10)

# %%
model = Sequential()
model.add(Input(shape=(28, 28, 1)))
model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
log_dir=join('logs','fit','model1')
tfcb=tf.keras.callbacks.TensorBoard(log_dir=log_dir,histogram_freq=1,write_graph=True)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test), callbacks=[tfcb], batch_size=32)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.6317 - loss: 2.6384 - val_accuracy: 0.8871 - val_loss: 0.4493
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9055 - loss: 0.3591 - val_accuracy: 0.9315 - val_loss: 0.2712
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9302 - loss: 0.2642 - val_accuracy: 0.9362 - val_loss: 0.2467
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9471 - loss: 0.1988 - val_accuracy: 0.9492 - val_loss: 0.2108
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9568 - loss: 0.1590 - val_accuracy: 0.9585 - val_loss: 0.1619
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9651 - loss: 0.1332 - val_accuracy: 0.9627 - val_loss: 0.1528
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9682 - loss: 0.1178 - val_accuracy: 0.9592 - val_loss: 0.1605
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9706 - loss: 0.1083 - val_accuracy: 0.9639 - val_loss: 0.1428
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9752 - loss: 0.0945 - val_accuracy: 0.9614 - val_loss: 0.1571
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9760 - loss: 0.0864 - val_accuracy: 0.9661 - val_loss: 0.1448

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/fit

# %%
model1 = Sequential()
model1.add(Input(shape=(28, 28, 1)))
model1.add(Flatten())
model1.add(Dense(64, activation='relu'),regularizers.l2(0.01))
model1.add(Dense(32, activation='relu'),regularizers.l2(0.01))
model1.add(Dense(16, activation='relu'),regularizers.l2(0.01))
model1.add(Dense(10, activation='softmax'))

# %%
log_dir=join('logs','fit','model1')
tfcbs=tf.keras.callbacks.TensorBoard(log_dir=log_dir,histogram_freq=1,write_graph=True)

# %%
model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model1.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test), callbacks=[tfcbs], batch_size=32)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.5357 - loss: 3.2692 - val_accuracy: 0.8732 - val_loss: 0.4493
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8904 - loss: 0.4068 - val_accuracy: 0.9068 - val_loss: 0.3395
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9269 - loss: 0.2689 - val_accuracy: 0.9386 - val_loss: 0.2340
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9457 - loss: 0.2021 - val_accuracy: 0.9444 - val_loss: 0.2247
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9539 - loss: 0.1740 - val_accuracy: 0.9455 - val_loss: 0.2009
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9604 - loss: 0.1438 - val_accuracy: 0.9583 - val_loss: 0.1655
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9633 - loss: 0.1305 - val_accuracy: 0.9585 - val_loss: 0.1714
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9675 - loss: 0.1194 - val_accuracy: 0.9534 - val_loss: 0.1855
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9713 - loss: 0.1018 - val_accuracy: 0.9635 - val_loss: 0.1602
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9726 - loss: 0.0907 - val_accuracy: 0.9603 - val_loss: 0.1726

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs/fit

# %%
model2 = Sequential()
model2.add(Input(shape=(28, 28, 1)))
model2.add(Flatten())
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(32, activation='relu'))
model2.add(Dense(16, activation='relu'))
model2.add(Dense(10, activation='softmax'))

# %%
log_dir = join('logs', 'fit', 'model2')
tfcbr = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1, write_graph=True)

# %%
model1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

history = model1.fit(x_train, y_train, epochs=10, validation_data=(x_test, y_test), callbacks=[tfcbr], batch_size=32)
# Out:
# Epoch 1/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.9744 - loss: 0.0892 - val_accuracy: 0.9595 - val_loss: 0.1687
# Epoch 2/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.9776 - loss: 0.0776 - val_accuracy: 0.9674 - val_loss: 0.1436
# Epoch 3/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9790 - loss: 0.0718 - val_accuracy: 0.9629 - val_loss: 0.1570
# Epoch 4/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9790 - loss: 0.0716 - val_accuracy: 0.9684 - val_loss: 0.1469
# Epoch 5/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9814 - loss: 0.0634 - val_accuracy: 0.9664 - val_loss: 0.1443
# Epoch 6/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9836 - loss: 0.0572 - val_accuracy: 0.9670 - val_loss: 0.1509
# Epoch 7/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9852 - loss: 0.0517 - val_accuracy: 0.9671 - val_loss: 0.1618
# Epoch 8/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9860 - loss: 0.0496 - val_accuracy: 0.9697 - val_loss: 0.1537
# Epoch 9/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 11s 4ms/step - accuracy: 0.9855 - loss: 0.0475 - val_accuracy: 0.9663 - val_loss: 0.1584
# Epoch 10/10
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 10s 5ms/step - accuracy: 0.9850 - loss: 0.0501 - val_accuracy: 0.9681 - val_loss: 0.1547

# %%
# %load_ext tensorboard
# # %tensorboard --logdir logs/fit
